# %%
from bs4 import BeautifulSoup
import datapackage
import datetime as dt
import numpy as np
import pandas as pd
import random 
import requests
import string

# %%
# columns
# ID - To be generated in MySQL
# Name
# State
# Type
# In Network

# %%
# create DataFrame
providers = pd.DataFrame()

# %%
# 1. types 
types = ['Behavioral Health', 'Cardiology', 'Dental', 'Dermatology', 'Durable Medical Equipment',\
         'Hospital', 'Internal Medicine', 'Neurology', 'OBGYN', 'Oncology', 'Orthodontics',\
         'Pediatrics', 'Physical Therapy', 'Primary Care', 'Urgent Care', 'Vision']


# capitalize each item in types list
provider_types = [i.upper() for i in types]

# %%
# 2. state/type colmns (company operates in the entire US, but primarily in the NE)
states = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# create weight function, code adapted from (https://www.python-course.eu/weighted_choice_and_sample.php)
def weighted_choice(objects, weights):
    """ returns a random element from the sequence of 'objects', 
        the likelihood of the objects is weighted according 
        to the sequence of 'weights', i.e. percentages."""

    weights = np.array(weights, dtype=np.float64)
    sum_of_weights = weights.sum()
    # standardization:
    np.multiply(weights, 1 / sum_of_weights, weights)
    weights = weights.cumsum()
    x = random.random()
    for i in range(len(weights)):
        if x < weights[i]:
            return objects[i]
        
# state weights, where each number represents the weight attached to each state in the data set. Higher weights
# mean that more providers will be from that state. NE states were given higher weights
state_weights = [3, 3, 6, 4, 20, 10, 7, 5, 10, 4, 
          1, 1, 10, 5, 3, 2, 8, 3, 8, 15, 
          30, 5, 5, 5, 5, 5, 2, 2, 6, 30, 
          2, 50, 20, 1, 20, 1, 1, 40, 6, 6, 
          1, 4, 10, 1, 6, 25, 5, 5, 4, 1]

# %%
# create state_type list, where the first operation ensures that each state has one of each type of provider,
# while the second fills out the last of the 3000 with random states based on calculated weights

# create a state_type list 
state_type = [f"{i} {j}" for i in states for j in types] 
state_type += [f"{weighted_choice(states, state_weights)} {random.choice(types)}" for i in range(3000-(len(state_type)))]

# %%
# create states list to be added to dataframe
# states = [i.split()[0] for i in state_type]

# %%
# create a state_type list for one and two-word states to be combined and added to dataframe
states2 = [i.split()[0] + ' ' + i.split()[1] for i in state_type if i.split()[0] + ' ' + i.split()[1] in states]
states1 = [i.split()[0] for i in state_type if i.split()[0] + ' ' + i.split()[1] not in states]
states_list = states2 + states1

# %%
# create a provider_type list for one and two-word states to be combined and added to dataframe
provider_types2 = [i.split()[2:] for i in state_type if i.split()[0] + ' ' + i.split()[1] in states2]
provider_types1 = [i.split()[1:] for i in state_type if i.split()[0] + ' ' + i.split()[1] not in states2]
provider_types = provider_types2 + provider_types1

# %%
# join strings in provider_types list 
provider_types = [' '.join(i) for i in provider_types]

# %%
# 3. Names (taken from US city names combined with various types of medicine)

# we will create in-network provider names using US city names attached to a provider type.
# city data pulled from https://datahub.io/core/country-list/r/0.html

# US city names
cities = pd.read_csv('world-cities_csv.csv')
us_cities = cities.query('country=="United States"')
us_cities = list(us_cities['name'])
# use a set to prevent duplicate entries, then convert to list
us_cities = {i.upper().split()[0] for i in us_cities if "-" not in i}
us_cities = list(us_cities)

# combine both city names to provider_types list to get provider names
names = [f"{random.choice(us_cities)} {provider_types[i].upper()}" for i in range(3000)]

# %%
# insert lists into dataframe
providers["Provider_Name"] = names
providers["State"] = states_list
providers["Type"] = provider_types

# %%
# sort dataframe and reset index
providers = providers.sort_values(by=['State', "Type"])

# %%
# 4. in-network

# 90% of providers are in network, 10% out of network
network = [weighted_choice(["In-network", "Out-of-network"], [0.9,0.1]) for i in range(3000)]

# %%
# insert network list into dataframe
providers['Network_Status'] = network

# %%
providers
# Out:
#                              Provider_Name      State  \
# 825              OPELIKA BEHAVIORAL HEALTH    Alabama
# 2602              DALTON BEHAVIORAL HEALTH    Alabama
# 826                      SPARKS CARDIOLOGY    Alabama
# 827                            PORT DENTAL    Alabama
# 2431                          UNION DENTAL    Alabama
# 828                       ERIE DERMATOLOGY    Alabama
# 829   MASSAPEQUA DURABLE MEDICAL EQUIPMENT    Alabama
# 830                      MARYLAND HOSPITAL    Alabama
# 831           CANTONMENT INTERNAL MEDICINE    Alabama
# 832                      MIDWEST NEUROLOGY    Alabama
# 2069                      KIRYAS NEUROLOGY    Alabama
# 2651                CHESTERFIELD NEUROLOGY    Alabama
# 2863                    APPLETON NEUROLOGY    Alabama
# 833                           POPLAR OBGYN    Alabama
# 1955                       PRUNEDALE OBGYN    Alabama
# 834                    MARYSVILLE ONCOLOGY    Alabama
# 1851                 RANDALLSTOWN ONCOLOGY    Alabama
# 2336                   AUSTINTOWN ONCOLOGY    Alabama
# 2649                     WILDOMAR ONCOLOGY    Alabama
# 835                   MINEOLA ORTHODONTICS    Alabama
# 836                     ROWLAND PEDIATRICS    Alabama
# 2182                   SOCASTEE PEDIATRICS    Alabama
# 2286                     IRVINE PEDIATRICS    Alabama
# 837                CASTRO PHYSICAL THERAPY    Alabama
# 2638         MERRILLVILLE PHYSICAL THERAPY    Alabama
# 838                 YORKVILLE PRIMARY CARE    Alabama
# 839                  MASSILLON URGENT CARE    Alabama
# 840                          FRESNO VISION    Alabama
# 1632                   KERNERSVILLE VISION    Alabama
# 841                PROVO BEHAVIORAL HEALTH     Alaska
# ...                                    ...        ...
# 1446               PIKESVILLE PRIMARY CARE  Wisconsin
# 1447                ELLENSBURG URGENT CARE  Wisconsin
# 1883                 PEEKSKILL URGENT CARE  Wisconsin
# 1905                       ST. URGENT CARE  Wisconsin
# 1448                         CICERO VISION  Wisconsin
# 1830                       ROSEMONT VISION  Wisconsin
# 1880                      POCATELLO VISION  Wisconsin
# 2144                        REXBURG VISION  Wisconsin
# 1449              DUNCAN BEHAVIORAL HEALTH    Wyoming
# 1450                     FOSTER CARDIOLOGY    Wyoming
# 1921                   WOODMERE CARDIOLOGY    Wyoming
# 1451                         LEHIGH DENTAL    Wyoming
# 1452                     NORCO DERMATOLOGY    Wyoming
# 1453       PIQUA DURABLE MEDICAL EQUIPMENT    Wyoming
# 2190     ROHNERT DURABLE MEDICAL EQUIPMENT    Wyoming
# 1454                      BALDWIN HOSPITAL    Wyoming
# 1455              POMONA INTERNAL MEDICINE    Wyoming
# 2396          BRIDGEVIEW INTERNAL MEDICINE    Wyoming
# 1456                     BOYNTON NEUROLOGY    Wyoming
# 1457                       POINCIANA OBGYN    Wyoming
# 1458                    GLASSBORO ONCOLOGY    Wyoming
# 1459                PITTSBURG ORTHODONTICS    Wyoming
# 1460                       BEAR PEDIATRICS    Wyoming
# 1461            VANCOUVER PHYSICAL THERAPY    Wyoming
# 2522              ATWATER PHYSICAL THERAPY    Wyoming
# 1462                    BIXBY PRIMARY CARE    Wyoming
# 1463                    CARSON URGENT CARE    Wyoming
# 2592                   BURBANK URGENT CARE    Wyoming
# 2603                   REDFORD URGENT CARE    Wyoming
# 1464                       FRANKLIN VISION    Wyoming
#
#                            Type  Network_Status
# 825           Behavioral Health  Out-of-network
# 2602          Behavioral Health      In-network
# 826                  Cardiology      In-network
# 827                      Dental      In-network
# 2431                     Dental  Out-of-network
# 828                 Dermatology      In-network
# 829   Durable Medical Equipment      In-network
# 830                    Hospital      In-network
# 831           Internal Medicine      In-network
# 832                   Neurology      In-network
# 2069                  Neurology      In-network
# 2651                  Neurology      In-network
# 2863                  Neurology      In-network
# 833                       OBGYN      In-network
# 1955                      OBGYN      In-network
# 834                    Oncology  Out-of-network
# 1851                   Oncology      In-network
# 2336                   Oncology      In-network
# 2649                   Oncology      In-network
# 835                Orthodontics      In-network
# 836                  Pediatrics      In-network
# 2182                 Pediatrics      In-network
# 2286                 Pediatrics      In-network
# 837            Physical Therapy      In-network
# 2638           Physical Therapy      In-network
# 838                Primary Care      In-network
# 839                 Urgent Care      In-network
# 840                      Vision      In-network
# 1632                     Vision      In-network
# 841           Behavioral Health      In-network
# ...                         ...             ...
# 1446               Primary Care      In-network
# 1447                Urgent Care      In-network
# 1883                Urgent Care      In-network
# 1905                Urgent Care      In-network
# 1448                     Vision  Out-of-network
# 1830                     Vision      In-network
# 1880                     Vision      In-network
# 2144                     Vision  Out-of-network
# 1449          Behavioral Health      In-network
# 1450                 Cardiology      In-network
# 1921                 Cardiology  Out-of-network
# 1451                     Dental      In-network
# 1452                Dermatology      In-network
# 1453  Durable Medical Equipment      In-network
# 2190  Durable Medical Equipment      In-network
# 1454                   Hospital      In-network
# 1455          Internal Medicine  Out-of-network
# 2396          Internal Medicine  Out-of-network
# 1456                  Neurology      In-network
# 1457                      OBGYN  Out-of-network
# 1458                   Oncology      In-network
# 1459               Orthodontics      In-network
# 1460                 Pediatrics      In-network
# 1461           Physical Therapy      In-network
# 2522           Physical Therapy      In-network
# 1462               Primary Care      In-network
# 1463                Urgent Care      In-network
# 2592                Urgent Care      In-network
# 2603                Urgent Care      In-network
# 1464                     Vision      In-network
#
# [3000 rows x 4 columns]

# %%
# SQL create table and insert
from sqlalchemy import create_engine
import pymysql

engine = create_engine('mysql+pymysql://root:funny20!@#@localhost')

# %%
# use the health_company database
engine.execute('USE health_company;')

# %%
# create providers table (CHANGE ORDER OF STATE ADN TYPE)
engine.execute('CREATE TABLE providers (\
	Provider_ID INT NOT NULL AUTO_INCREMENT,\
	Provider_Name VARCHAR(50),\
    State VARCHAR(20),\
    Type VARCHAR(50),\
    Network_Status VARCHAR(50),\
    PRIMARY KEY(Provider_ID)\
    ) AUTO_INCREMENT = 200000;')

# %%
# show tables to verify table creation
engine.execute('SHOW TABLES').fetchall()
# Out:
# [('drugs',),
#  ('members',),
#  ('pharmacies',),
#  ('procedure_claims',),
#  ('procedures',),
#  ('providers',),
#  ('rx_claims',),
#  ('states',)]

# %%
# describe pharmacy table to verify columns
engine.execute('DESC providers;').fetchall()
# Out:
# [('Provider_ID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('Provider_Name', 'varchar(50)', 'YES', '', None, ''),
#  ('State', 'varchar(20)', 'YES', '', None, ''),
#  ('Type', 'varchar(50)', 'YES', '', None, ''),
#  ('Network_Status', 'varchar(50)', 'YES', '', None, '')]

# %%
# write to providers table
providers.to_sql('providers', con=engine, if_exists='append', index=False)

# %%
# select providers table
engine.execute('SELECT * FROM providers;').fetchall()
# Out:
# [(200000, 'OPELIKA BEHAVIORAL HEALTH', 'Alabama', 'Behavioral Health', 'Out-of-network'),
#  (200001, 'DALTON BEHAVIORAL HEALTH', 'Alabama', 'Behavioral Health', 'In-network'),
#  (200002, 'SPARKS CARDIOLOGY', 'Alabama', 'Cardiology', 'In-network'),
#  (200003, 'PORT DENTAL', 'Alabama', 'Dental', 'In-network'),
#  (200004, 'UNION DENTAL', 'Alabama', 'Dental', 'Out-of-network'),
#  (200005, 'ERIE DERMATOLOGY', 'Alabama', 'Dermatology', 'In-network'),
#  (200006, 'MASSAPEQUA DURABLE MEDICAL EQUIPMENT', 'Alabama', 'Durable Medical Equipment', 'In-network'),
#  (200007, 'MARYLAND HOSPITAL', 'Alabama', 'Hospital', 'In-network'),
#  (200008, 'CANTONMENT INTERNAL MEDICINE', 'Alabama', 'Internal Medicine', 'In-network'),
#  (200009, 'MIDWEST NEUROLOGY', 'Alabama', 'Neurology', 'In-network'),
#  (200010, 'KIRYAS NEUROLOGY', 'Alabama', 'Neurology', 'In-network'),
#  (200011, 'CHESTERFIELD NEUROLOGY', 'Alabama', 'Neurology', 'In-network'),
#  (200012, 'APPLETON NEUROLOGY', 'Alabama', 'Neurology', 'In-network'),
#  (200013, 'POPLAR OBGYN', 'Alabama', 'OBGYN', 'In-network'),
#  (200014, 'PRUNEDALE OBGYN', 'Alabama', 'OBGYN', 'In-network'),
#  (200015, 'MARYSVILLE ONCOLOGY', 'Alabama', 'Oncology', 'Out-of-network'),
#  (200016, 'RANDALLSTOWN ONCOLOGY', 'Alabama', 'Oncology', 'In-network'),
#  (200017, 'AUSTINTOWN ONCOLOGY', 'Alabama', 'Oncology', 'In-network'),
#  (200018, 'WILDOMAR ONCOLOGY', 'Alabama', 'Oncology', 'In-network'),
#  (200019, 'MINEOLA ORTHODONTICS', 'Alabama', 'Orthodontics', 'In-network'),
#  (200020, 'ROWLAND PEDIATRICS', 'Alabama', 'Pediatrics', 'In-network'),
#  (200021, 'SOCASTEE PEDIATRICS', 'Alabama', 'Pediatrics', 'In-network'),
#  (200022, 'IRVINE PEDIATRICS', 'Alabama', 'Pediatrics', 'In-network'),
#  (200023, 'CASTRO PHYSICAL THERAPY', 'Alabama', 'Physical Therapy', 'In-network'),
#  (200024, 'MERRILLVILLE PHYSICAL THERAPY', 'Alabama', 'Physical Therapy', 'In-network'),
#  (200025, 'YORKVILLE PRIMARY CARE', 'Alabama', 'Primary Care', 'In-network'),
#  (200026, 'MASSILLON URGENT CARE', 'Alabama', 'Urgent Care', 'In-network'),
#  (200027, 'FRESNO VISION', 'Alabama', 'Vision', 'In-network'),
#  (200028, 'KERNERSVILLE VISION', 'Alabama', 'Vision', 'In-network'),
#  (200029, 'PROVO BEHAVIORAL HEALTH', 'Alaska', 'Behavioral Health', 'In-network'),
#  (200030, 'GOOSE BEHAVIORAL HEALTH', 'Alaska', 'Behavioral Health', 'In-network'),
#  (200031, 'FRAMINGHAM BEHAVIORAL HEALTH', 'Alaska', 'Behavioral Health', 'In-network'),
#  (200032, 'ARROYO CARDIOLOGY', 'Alaska', 'Cardiology', 'In-network'),
#  (200033, 'ROGERS DENTAL', 'Alaska', 'Dental', 'In-network'),
#  (200034, 'FORREST DENTAL', 'Alaska', 'Dental', 'In-network'),
#  (200035, 'EVERGREEN DERMATOLOGY', 'Alaska', 'Dermatology', 'In-network'),
#  (200036, 'NORMAN DERMATOLOGY', 'Alaska', 'Dermatology', 'In-network'),
#  (200037, 'LAKE DURABLE MEDICAL EQUIPMENT', 'Alaska', 'Durable Medical Equipment', 'In-network'),
#  (200038, 'INDEPENDENCE DURABLE MEDICAL EQUIPMENT', 'Alaska', 'Durable Medical Equipment', 'In-network'),
#  (200039, 'MOORESVILLE HOSPITAL', 'Alaska', 'Hospital', 'In-network'),
#  (200040, 'ROLLING HOSPITAL', 'Alaska', 'Hospital', 'In-network'),
#  (200041, 'BARTLESVILLE HOSPITAL', 'Alaska', 'Hospital', 'In-network'),
#  (200042, 'EAGLE INTERNAL MEDICINE', 'Alaska', 'Internal Medicine', 'Out-of-network'),
#  (200043, 'LINDEN INTERNAL MEDICINE', 'Alaska', 'Internal Medicine', 'In-network'),
#  (200044, 'DOUGLASVILLE NEUROLOGY', 'Alaska', 'Neurology', 'In-network'),
#  (200045, 'ANGLETON NEUROLOGY', 'Alaska', 'Neurology', 'In-network'),
#  (200046, 'BUFFALO OBGYN', 'Alaska', 'OBGYN', 'In-network'),
#  (200047, 'ENID OBGYN', 'Alaska', 'OBGYN', 'In-network'),
#  (200048, 'SEABROOK OBGYN', 'Alaska', 'OBGYN', 'Out-of-network'),
#  (200049, 'CHARLOTTE OBGYN', 'Alaska', 'OBGYN', 'In-network'),
#  (200050, 'WINTER ONCOLOGY', 'Alaska', 'Oncology', 'Out-of-network'),
#  (200051, 'OXON ONCOLOGY', 'Alaska', 'Oncology', 'In-network'),
#  (200052, 'RAMSEY ORTHODONTICS', 'Alaska', 'Orthodontics', 'In-network'),
#  (200053, 'MORAGA PEDIATRICS', 'Alaska', 'Pediatrics', 'In-network'),
#  (200054, "O'FALLON PEDIATRICS", 'Alaska', 'Pediatrics', 'In-network'),
#  (200055, 'BROOKINGS PEDIATRICS', 'Alaska', 'Pediatrics', 'In-network'),
#  (200056, 'BERKELEY PEDIATRICS', 'Alaska', 'Pediatrics', 'In-network'),
#  (200057, 'ONTARIO PEDIATRICS', 'Alaska', 'Pediatrics', 'In-network'),
#  (200058, 'CORAM PHYSICAL THERAPY', 'Alaska', 'Physical Therapy', 'In-network'),
#  (200059, 'APPLE PHYSICAL THERAPY', 'Alaska', 'Physical Therapy', 'In-network'),
#  (200060, 'HUNTLEY PRIMARY CARE', 'Alaska', 'Primary Care', 'In-network'),
#  (200061, 'RANCHO URGENT CARE', 'Alaska', 'Urgent Care', 'In-network'),
#  (200062, 'WILLINGBORO URGENT CARE', 'Alaska', 'Urgent Care', 'In-network'),
#  (200063, 'CENTER VISION', 'Alaska', 'Vision', 'In-network'),
#  (200064, 'EDGEWOOD BEHAVIORAL HEALTH', 'Arizona', 'Behavioral Health', 'In-network'),
#  (200065, 'BISMARCK BEHAVIORAL HEALTH', 'Arizona', 'Behavioral Health', 'In-network'),
#  (200066, 'LEHI BEHAVIORAL HEALTH', 'Arizona', 'Behavioral Health', 'In-network'),
#  (200067, 'POWAY BEHAVIORAL HEALTH', 'Arizona', 'Behavioral Health', 'In-network'),
#  (200068, 'ELKHART CARDIOLOGY', 'Arizona', 'Cardiology', 'In-network'),
#  (200069, 'ROOSEVELT CARDIOLOGY', 'Arizona', 'Cardiology', 'In-network'),
#  (200070, 'PONTIAC DENTAL', 'Arizona', 'Dental', 'In-network'),
#  (200071, 'STREETSBORO DENTAL', 'Arizona', 'Dental', 'In-network'),
#  (200072, 'DURANGO DENTAL', 'Arizona', 'Dental', 'In-network'),
#  (200073, 'SHENANDOAH DERMATOLOGY', 'Arizona', 'Dermatology', 'In-network'),
#  (200074, 'LAUDERDALE DERMATOLOGY', 'Arizona', 'Dermatology', 'In-network'),
#  (200075, 'LEHI DERMATOLOGY', 'Arizona', 'Dermatology', 'In-network'),
#  (200076, 'ARCADIA DERMATOLOGY', 'Arizona', 'Dermatology', 'In-network'),
#  (200077, 'ELMONT DURABLE MEDICAL EQUIPMENT', 'Arizona', 'Durable Medical Equipment', 'In-network'),
#  (200078, 'IRVINE DURABLE MEDICAL EQUIPMENT', 'Arizona', 'Durable Medical Equipment', 'In-network'),
#  (200079, 'ENTERPRISE DURABLE MEDICAL EQUIPMENT', 'Arizona', 'Durable Medical Equipment', 'In-network'),
#  (200080, 'DYERSBURG DURABLE MEDICAL EQUIPMENT', 'Arizona', 'Durable Medical Equipment', 'In-network'),
#  (200081, 'AUSTIN HOSPITAL', 'Arizona', 'Hospital', 'In-network'),
#  (200082, 'STREAMWOOD INTERNAL MEDICINE', 'Arizona', 'Internal Medicine', 'In-network'),
#  (200083, 'CENTER INTERNAL MEDICINE', 'Arizona', 'Internal Medicine', 'In-network'),
#  (200084, 'PENN INTERNAL MEDICINE', 'Arizona', 'Internal Medicine', 'In-network'),
#  (200085, 'GREENWOOD NEUROLOGY', 'Arizona', 'Neurology', 'In-network'),
#  (200086, 'CAMAS NEUROLOGY', 'Arizona', 'Neurology', 'In-network'),
#  (200087, 'PIKESVILLE NEUROLOGY', 'Arizona', 'Neurology', 'In-network'),
#  (200088, 'GOLDSBORO NEUROLOGY', 'Arizona', 'Neurology', 'In-network'),
#  (200089, 'LAND OBGYN', 'Arizona', 'OBGYN', 'In-network'),
#  (200090, 'CLOVERLEAF OBGYN', 'Arizona', 'OBGYN', 'In-network'),
#  (200091, 'RAYTOWN ONCOLOGY', 'Arizona', 'Oncology', 'In-network'),
#  (200092, 'CLEARLAKE ONCOLOGY', 'Arizona', 'Oncology', 'In-network'),
#  (200093, 'BAYTOWN ORTHODONTICS', 'Arizona', 'Orthodontics', 'In-network'),
#  (200094, 'DERBY ORTHODONTICS', 'Arizona', 'Orthodontics', 'Out-of-network'),
#  (200095, 'GREER ORTHODONTICS', 'Arizona', 'Orthodontics', 'In-network'),
#  (200096, 'SIMPSONVILLE PEDIATRICS', 'Arizona', 'Pediatrics', 'In-network'),
#  (200097, 'CIMARRON PHYSICAL THERAPY', 'Arizona', 'Physical Therapy', 'In-network'),
#  (200098, 'COLLIERVILLE PHYSICAL THERAPY', 'Arizona', 'Physical Therapy', 'In-network'),
#  (200099, 'LEMAY PRIMARY CARE', 'Arizona', 'Primary Care', 'In-network'),
#  (200100, 'MUSKOGEE PRIMARY CARE', 'Arizona', 'Primary Care', 'Out-of-network'),
#  (200101, 'MUSTANG PRIMARY CARE', 'Arizona', 'Primary Care', 'In-network'),
#  (200102, 'WESTPORT URGENT CARE', 'Arizona', 'Urgent Care', 'In-network'),
#  (200103, 'PORTLAND URGENT CARE', 'Arizona', 'Urgent Care', 'In-network'),
#  (200104, 'FOSTER VISION', 'Arizona', 'Vision', 'In-network'),
#  (200105, 'LANDOVER BEHAVIORAL HEALTH', 'Arkansas', 'Behavioral Health', 'In-network'),
#  (200106, 'ALLAPATTAH BEHAVIORAL HEALTH', 'Arkansas', 'Behavioral Health', 'Out-of-network'),
#  (200107, 'WAUKESHA CARDIOLOGY', 'Arkansas', 'Cardiology', 'In-network'),
#  (200108, 'BURNSVILLE CARDIOLOGY', 'Arkansas', 'Cardiology', 'In-network'),
#  (200109, 'DENTON CARDIOLOGY', 'Arkansas', 'Cardiology', 'In-network'),
#  (200110, 'PEMBROKE CARDIOLOGY', 'Arkansas', 'Cardiology', 'In-network'),
#  (200111, 'BULLHEAD DENTAL', 'Arkansas', 'Dental', 'In-network'),
#  (200112, 'UPPER DENTAL', 'Arkansas', 'Dental', 'In-network'),
#  (200113, 'LONGVIEW DERMATOLOGY', 'Arkansas', 'Dermatology', 'In-network'),
#  (200114, 'MILPITAS DERMATOLOGY', 'Arkansas', 'Dermatology', 'In-network'),
#  (200115, 'PORTSMOUTH DURABLE MEDICAL EQUIPMENT', 'Arkansas', 'Durable Medical Equipment', 'In-network'),
#  (200116, 'THREE DURABLE MEDICAL EQUIPMENT', 'Arkansas', 'Durable Medical Equipment', 'In-network'),
#  (200117, 'HACIENDA DURABLE MEDICAL EQUIPMENT', 'Arkansas', 'Durable Medical Equipment', 'In-network'),
#  (200118, 'ESSEX HOSPITAL', 'Arkansas', 'Hospital', 'In-network'),
#  (200119, 'BARBERTON INTERNAL MEDICINE', 'Arkansas', 'Internal Medicine', 'In-network'),
#  (200120, 'LYNWOOD NEUROLOGY', 'Arkansas', 'Neurology', 'In-network'),
#  (200121, 'ROUND NEUROLOGY', 'Arkansas', 'Neurology', 'In-network'),
#  (200122, 'LINDENHURST NEUROLOGY', 'Arkansas', 'Neurology', 'In-network'),
#  (200123, 'CUYAHOGA OBGYN', 'Arkansas', 'OBGYN', 'Out-of-network'),
#  (200124, 'MENIFEE OBGYN', 'Arkansas', 'OBGYN', 'In-network'),
#  (200125, 'PLUM ONCOLOGY', 'Arkansas', 'Oncology', 'Out-of-network'),
#  (200126, 'DUNEDIN ONCOLOGY', 'Arkansas', 'Oncology', 'In-network'),
#  (200127, 'CRANSTON ONCOLOGY', 'Arkansas', 'Oncology', 'In-network'),
#  (200128, 'RAMONA ORTHODONTICS', 'Arkansas', 'Orthodontics', 'In-network'),
#  (200129, 'ALBANY ORTHODONTICS', 'Arkansas', 'Orthodontics', 'In-network'),
#  (200130, 'CLAYTON ORTHODONTICS', 'Arkansas', 'Orthodontics', 'In-network'),
#  (200131, 'SIMPSONVILLE ORTHODONTICS', 'Arkansas', 'Orthodontics', 'In-network'),
#  (200132, 'HAMILTON PEDIATRICS', 'Arkansas', 'Pediatrics', 'In-network'),
#  (200133, 'FARMINGVILLE PEDIATRICS', 'Arkansas', 'Pediatrics', 'In-network'),
#  (200134, 'HOLYOKE PHYSICAL THERAPY', 'Arkansas', 'Physical Therapy', 'In-network'),
#  (200135, 'CHALMETTE PHYSICAL THERAPY', 'Arkansas', 'Physical Therapy', 'Out-of-network'),
#  (200136, 'FAYETTEVILLE PHYSICAL THERAPY', 'Arkansas', 'Physical Therapy', 'In-network'),
#  (200137, 'CLOVERLY PRIMARY CARE', 'Arkansas', 'Primary Care', 'In-network'),
#  (200138, 'VILLA PRIMARY CARE', 'Arkansas', 'Primary Care', 'In-network'),
#  (200139, 'ISLIP PRIMARY CARE', 'Arkansas', 'Primary Care', 'In-network'),
#  (200140, 'PALMDALE URGENT CARE', 'Arkansas', 'Urgent Care', 'In-network'),
#  (200141, 'ROLLA URGENT CARE', 'Arkansas', 'Urgent Care', 'In-network'),
#  (200142, 'LYNWOOD VISION', 'Arkansas', 'Vision', 'In-network'),
#  (200143, 'INDIANAPOLIS BEHAVIORAL HEALTH', 'California', 'Behavioral Health', 'In-network'),
#  (200144, 'CANBY BEHAVIORAL HEALTH', 'California', 'Behavioral Health', 'In-network'),
#  (200145, 'CHALMETTE BEHAVIORAL HEALTH', 'California', 'Behavioral Health', 'Out-of-network'),
#  (200146, 'ANNAPOLIS BEHAVIORAL HEALTH', 'California', 'Behavioral Health', 'In-network'),
#  (200147, 'MORGANTON BEHAVIORAL HEALTH', 'California', 'Behavioral Health', 'In-network'),
#  (200148, 'LEVITTOWN CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200149, 'ENID CARDIOLOGY', 'California', 'Cardiology', 'Out-of-network'),
#  (200150, 'KNOXVILLE CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200151, 'TUMWATER CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200152, 'RENO CARDIOLOGY', 'California', 'Cardiology', 'Out-of-network'),
#  (200153, 'MIRAMAR CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200154, 'LINDEN CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200155, 'ENCHANTED CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200156, 'HARVEY CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200157, 'MORGAN CARDIOLOGY', 'California', 'Cardiology', 'In-network'),
#  (200158, 'GARDENA DENTAL', 'California', 'Dental', 'In-network'),
#  (200159, 'ELIZABETHTOWN DENTAL', 'California', 'Dental', 'In-network'),
#  (200160, 'LYNNWOOD DENTAL', 'California', 'Dental', 'In-network'),
#  (200161, 'HELENA DENTAL', 'California', 'Dental', 'Out-of-network'),
#  (200162, 'PASO DENTAL', 'California', 'Dental', 'In-network'),
#  (200163, 'MOORPARK DENTAL', 'California', 'Dental', 'In-network'),
#  (200164, 'JERSEY DENTAL', 'California', 'Dental', 'In-network'),
#  (200165, 'SCOTTSDALE DENTAL', 'California', 'Dental', 'Out-of-network'),
#  (200166, 'AUSTINTOWN DENTAL', 'California', 'Dental', 'In-network'),
#  (200167, 'MURRAY DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200168, 'OAKLEY DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200169, 'SALMON DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200170, 'BROOKINGS DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200171, 'GLENDORA DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200172, 'ROCKY DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200173, 'TROUTDALE DERMATOLOGY', 'California', 'Dermatology', 'In-network'),
#  (200174, 'OVIEDO DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200175, 'ENID DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200176, 'BELLA DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200177, 'HIBBING DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200178, 'WAVERLY DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200179, 'WESTPORT DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200180, 'MARLBOROUGH DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200181, 'EASTPOINTE DURABLE MEDICAL EQUIPMENT', 'California', 'Durable Medical Equipment', 'In-network'),
#  (200182, 'RIDGEWOOD HOSPITAL', 'California', 'Hospital', 'In-network'),
#  (200183, 'DESERT HOSPITAL', 'California', 'Hospital', 'In-network'),
#  (200184, 'OSWEGO HOSPITAL', 'California', 'Hospital', 'In-network'),
#  (200185, 'BAYONET HOSPITAL', 'California', 'Hospital', 'Out-of-network'),
#  (200186, 'PASADENA HOSPITAL', 'California', 'Hospital', 'In-network'),
#  (200187, 'NATICK HOSPITAL', 'California', 'Hospital', 'In-network'),
#  (200188, 'BROOKHAVEN INTERNAL MEDICINE', 'California', 'Internal Medicine', 'In-network'),
#  (200189, 'FORDS INTERNAL MEDICINE', 'California', 'Internal Medicine', 'In-network'),
#  (200190, 'DENVER INTERNAL MEDICINE', 'California', 'Internal Medicine', 'In-network'),
#  (200191, 'ALBERT INTERNAL MEDICINE', 'California', 'Internal Medicine', 'In-network'),
#  (200192, 'MOUNTLAKE INTERNAL MEDICINE', 'California', 'Internal Medicine', 'Out-of-network'),
#  (200193, 'CLEARWATER NEUROLOGY', 'California', 'Neurology', 'In-network'),
#  (200194, 'BOYLE NEUROLOGY', 'California', 'Neurology', 'In-network'),
#  (200195, 'STERLING NEUROLOGY', 'California', 'Neurology', 'Out-of-network'),
#  (200196, 'CASAS NEUROLOGY', 'California', 'Neurology', 'In-network'),
#  (200197, 'HOLLISTER NEUROLOGY', 'California', 'Neurology', 'Out-of-network'),
#  (200198, 'HIALEAH NEUROLOGY', 'California', 'Neurology', 'In-network'),
#  (200199, 'DAVENPORT OBGYN', 'California', 'OBGYN', 'In-network'),
#  (200200, 'PINEWOOD OBGYN', 'California', 'OBGYN', 'In-network'),
#  (200201, 'ONTARIO OBGYN', 'California', 'OBGYN', 'Out-of-network'),
#  (200202, 'CRAWFORDSVILLE OBGYN', 'California', 'OBGYN', 'In-network'),
#  (200203, 'CUYAHOGA OBGYN', 'California', 'OBGYN', 'In-network'),
#  (200204, 'DEFIANCE OBGYN', 'California', 'OBGYN', 'In-network'),
#  (200205, 'HOPATCONG OBGYN', 'California', 'OBGYN', 'In-network'),
#  (200206, 'KAUKAUNA ONCOLOGY', 'California', 'Oncology', 'In-network'),
#  (200207, 'LOGAN ONCOLOGY', 'California', 'Oncology', 'In-network'),
#  (200208, 'NORCO ONCOLOGY', 'California', 'Oncology', 'In-network'),
#  (200209, 'GREENSBORO ONCOLOGY', 'California', 'Oncology', 'In-network'),
#  (200210, 'WESTCHASE ONCOLOGY', 'California', 'Oncology', 'In-network'),
#  (200211, 'CUDAHY ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200212, 'RIVERTON ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200213, 'HIGHVIEW ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200214, 'BATON ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200215, 'SELMA ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200216, 'MONTGOMERY ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200217, 'DOWNERS ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200218, 'MONTEBELLO ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200219, 'HIALEAH ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200220, 'HARRISBURG ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200221, 'MISSOULA ORTHODONTICS', 'California', 'Orthodontics', 'In-network'),
#  (200222, 'PUYALLUP PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200223, 'MINOT PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200224, 'EDWARDSVILLE PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200225, 'TUKWILA PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200226, 'GARDEN PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200227, 'BROKEN PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200228, 'FLORAL PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200229, 'BLOOMINGDALE PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200230, 'ALICE PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200231, 'HAYS PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200232, 'LONGMEADOW PEDIATRICS', 'California', 'Pediatrics', 'In-network'),
#  (200233, 'ROMULUS PEDIATRICS', 'California', 'Pediatrics', 'Out-of-network'),
#  (200234, 'MILTON PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200235, 'ROANOKE PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200236, 'MCDONOUGH PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200237, 'GLASSMANOR PHYSICAL THERAPY', 'California', 'Physical Therapy', 'Out-of-network'),
#  (200238, 'KEARNY PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200239, 'RAMSEY PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200240, 'PINOLE PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200241, 'INDEPENDENCE PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200242, 'FLAGSTAFF PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200243, 'BEAVERCREEK PHYSICAL THERAPY', 'California', 'Physical Therapy', 'In-network'),
#  (200244, 'NICHOLASVILLE PRIMARY CARE', 'California', 'Primary Care', 'In-network'),
#  (200245, 'LIMERICK PRIMARY CARE', 'California', 'Primary Care', 'In-network'),
#  (200246, 'WHEAT PRIMARY CARE', 'California', 'Primary Care', 'In-network'),
#  (200247, 'PAINESVILLE PRIMARY CARE', 'California', 'Primary Care', 'In-network'),
#  (200248, 'COLLEYVILLE PRIMARY CARE', 'California', 'Primary Care', 'In-network'),
#  (200249, 'PAROLE URGENT CARE', 'California', 'Urgent Care', 'In-network'),
#  (200250, 'UPLAND URGENT CARE', 'California', 'Urgent Care', 'In-network'),
#  (200251, 'WALLINGFORD URGENT CARE', 'California', 'Urgent Care', 'In-network'),
#  (200252, 'MOSES URGENT CARE', 'California', 'Urgent Care', 'In-network'),
#  (200253, 'HORIZON VISION', 'California', 'Vision', 'In-network'),
#  (200254, 'POPLAR VISION', 'California', 'Vision', 'In-network'),
#  (200255, 'STREETSBORO VISION', 'California', 'Vision', 'In-network'),
#  (200256, 'MARION VISION', 'California', 'Vision', 'Out-of-network'),
#  (200257, 'ALGONQUIN VISION', 'California', 'Vision', 'Out-of-network'),
#  (200258, 'WILKINSBURG VISION', 'California', 'Vision', 'In-network'),
#  (200259, 'PIKESVILLE BEHAVIORAL HEALTH', 'Colorado', 'Behavioral Health', 'In-network'),
#  (200260, 'WILLOWBROOK BEHAVIORAL HEALTH', 'Colorado', 'Behavioral Health', 'In-network'),
#  (200261, 'LA BEHAVIORAL HEALTH', 'Colorado', 'Behavioral Health', 'In-network'),
#  (200262, 'WHITTIER BEHAVIORAL HEALTH', 'Colorado', 'Behavioral Health', 'In-network'),
#  (200263, 'MANITOWOC CARDIOLOGY', 'Colorado', 'Cardiology', 'In-network'),
#  (200264, 'AVENAL CARDIOLOGY', 'Colorado', 'Cardiology', 'Out-of-network'),
#  (200265, 'COLLIERVILLE CARDIOLOGY', 'Colorado', 'Cardiology', 'In-network'),
#  (200266, 'DENISON CARDIOLOGY', 'Colorado', 'Cardiology', 'In-network'),
#  (200267, 'STATEN DENTAL', 'Colorado', 'Dental', 'In-network'),
#  (200268, 'JAMAICA DENTAL', 'Colorado', 'Dental', 'In-network'),
#  (200269, 'CALEXICO DENTAL', 'Colorado', 'Dental', 'In-network'),
#  (200270, 'ESCONDIDO DENTAL', 'Colorado', 'Dental', 'In-network'),
#  (200271, 'BROOKINGS DENTAL', 'Colorado', 'Dental', 'In-network'),
#  (200272, 'WHITE DERMATOLOGY', 'Colorado', 'Dermatology', 'In-network'),
#  (200273, 'STEUBENVILLE DERMATOLOGY', 'Colorado', 'Dermatology', 'In-network'),
#  (200274, 'CHERRY DERMATOLOGY', 'Colorado', 'Dermatology', 'In-network'),
#  (200275, 'UNIONDALE DERMATOLOGY', 'Colorado', 'Dermatology', 'In-network'),
#  (200276, 'NATICK DERMATOLOGY', 'Colorado', 'Dermatology', 'In-network'),
#  (200277, 'PALOS DERMATOLOGY', 'Colorado', 'Dermatology', 'In-network'),
#  (200278, 'LAWRENCE DURABLE MEDICAL EQUIPMENT', 'Colorado', 'Durable Medical Equipment', 'In-network'),
#  (200279, 'POTOMAC DURABLE MEDICAL EQUIPMENT', 'Colorado', 'Durable Medical Equipment', 'Out-of-network'),
#  (200280, 'GURNEE DURABLE MEDICAL EQUIPMENT', 'Colorado', 'Durable Medical Equipment', 'Out-of-network'),
#  (200281, 'LENOIR HOSPITAL', 'Colorado', 'Hospital', 'In-network'),
#  (200282, 'BOSTON HOSPITAL', 'Colorado', 'Hospital', 'In-network'),
#  (200283, 'BRANDON HOSPITAL', 'Colorado', 'Hospital', 'In-network'),
#  (200284, 'PAWTUCKET HOSPITAL', 'Colorado', 'Hospital', 'In-network'),
#  (200285, 'TULARE INTERNAL MEDICINE', 'Colorado', 'Internal Medicine', 'In-network'),
#  (200286, 'LINO INTERNAL MEDICINE', 'Colorado', 'Internal Medicine', 'In-network'),
#  (200287, 'STATEN INTERNAL MEDICINE', 'Colorado', 'Internal Medicine', 'In-network'),
#  (200288, 'ORO INTERNAL MEDICINE', 'Colorado', 'Internal Medicine', 'In-network'),
#  (200289, 'LAUDERHILL NEUROLOGY', 'Colorado', 'Neurology', 'In-network'),
#  (200290, 'COLLINSVILLE NEUROLOGY', 'Colorado', 'Neurology', 'In-network'),
#  (200291, 'RUTLAND NEUROLOGY', 'Colorado', 'Neurology', 'In-network'),
#  (200292, 'MARYLAND OBGYN', 'Colorado', 'OBGYN', 'In-network'),
#  (200293, 'LENOIR OBGYN', 'Colorado', 'OBGYN', 'In-network'),
#  (200294, 'MILWAUKEE OBGYN', 'Colorado', 'OBGYN', 'In-network'),
#  (200295, 'WADE OBGYN', 'Colorado', 'OBGYN', 'In-network'),
#  (200296, 'HAVERHILL OBGYN', 'Colorado', 'OBGYN', 'In-network'),
#  (200297, 'BOISE ONCOLOGY', 'Colorado', 'Oncology', 'In-network'),
#  (200298, 'TOWN ONCOLOGY', 'Colorado', 'Oncology', 'In-network'),
#  (200299, 'CINCINNATI ONCOLOGY', 'Colorado', 'Oncology', 'In-network'),
#  (200300, 'ORMOND ONCOLOGY', 'Colorado', 'Oncology', 'In-network'),
#  (200301, 'FREMONT ONCOLOGY', 'Colorado', 'Oncology', 'In-network'),
#  (200302, 'EAST ONCOLOGY', 'Colorado', 'Oncology', 'Out-of-network'),
#  (200303, 'LOGAN ONCOLOGY', 'Colorado', 'Oncology', 'In-network'),
#  (200304, 'KAUKAUNA ONCOLOGY', 'Colorado', 'Oncology', 'Out-of-network'),
#  (200305, 'KIRKWOOD ORTHODONTICS', 'Colorado', 'Orthodontics', 'In-network'),
#  (200306, 'KERNERSVILLE ORTHODONTICS', 'Colorado', 'Orthodontics', 'In-network'),
#  (200307, 'NUTLEY ORTHODONTICS', 'Colorado', 'Orthodontics', 'In-network'),
#  (200308, 'CONVERSE PEDIATRICS', 'Colorado', 'Pediatrics', 'In-network'),
#  (200309, 'CAHOKIA PEDIATRICS', 'Colorado', 'Pediatrics', 'In-network'),
#  (200310, 'CLINTON PEDIATRICS', 'Colorado', 'Pediatrics', 'In-network'),
#  (200311, 'LAND PEDIATRICS', 'Colorado', 'Pediatrics', 'In-network'),
#  (200312, 'TUKWILA PHYSICAL THERAPY', 'Colorado', 'Physical Therapy', 'In-network'),
#  (200313, 'MONTEBELLO PHYSICAL THERAPY', 'Colorado', 'Physical Therapy', 'In-network'),
#  (200314, 'HERMITAGE PHYSICAL THERAPY', 'Colorado', 'Physical Therapy', 'In-network'),
#  (200315, 'COLLINSVILLE PHYSICAL THERAPY', 'Colorado', 'Physical Therapy', 'In-network'),
#  (200316, 'MEAD PHYSICAL THERAPY', 'Colorado', 'Physical Therapy', 'In-network'),
#  (200317, 'INGLEWOOD PHYSICAL THERAPY', 'Colorado', 'Physical Therapy', 'In-network'),
#  (200318, 'KERNERSVILLE PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200319, 'GREENBURGH PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200320, 'GATESVILLE PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200321, 'DE PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200322, 'HOUSTON PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200323, 'WEKIWA PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200324, 'BROOKINGS PRIMARY CARE', 'Colorado', 'Primary Care', 'Out-of-network'),
#  (200325, 'POINT PRIMARY CARE', 'Colorado', 'Primary Care', 'In-network'),
#  (200326, 'WADSWORTH URGENT CARE', 'Colorado', 'Urgent Care', 'In-network'),
#  (200327, 'HUMBLE URGENT CARE', 'Colorado', 'Urgent Care', 'In-network'),
#  (200328, 'BETHEL URGENT CARE', 'Colorado', 'Urgent Care', 'In-network'),
#  (200329, 'WOODSTOCK URGENT CARE', 'Colorado', 'Urgent Care', 'In-network'),
#  (200330, 'WENTZVILLE URGENT CARE', 'Colorado', 'Urgent Care', 'In-network'),
#  (200331, 'FARMINGTON URGENT CARE', 'Colorado', 'Urgent Care', 'In-network'),
#  (200332, 'KIRKLAND VISION', 'Colorado', 'Vision', 'In-network'),
#  (200333, 'CHELSEA VISION', 'Colorado', 'Vision', 'In-network'),
#  (200334, 'BELLEVILLE VISION', 'Colorado', 'Vision', 'In-network'),
#  (200335, 'MODESTO VISION', 'Colorado', 'Vision', 'In-network'),
#  (200336, 'COLTON BEHAVIORAL HEALTH', 'Connecticut', 'Behavioral Health', 'Out-of-network'),
#  (200337, 'ELKRIDGE BEHAVIORAL HEALTH', 'Connecticut', 'Behavioral Health', 'In-network'),
#  (200338, 'MARYVILLE BEHAVIORAL HEALTH', 'Connecticut', 'Behavioral Health', 'Out-of-network'),
#  (200339, 'OPELIKA BEHAVIORAL HEALTH', 'Connecticut', 'Behavioral Health', 'In-network'),
#  (200340, 'JASMINE CARDIOLOGY', 'Connecticut', 'Cardiology', 'In-network'),
#  (200341, 'ATHENS CARDIOLOGY', 'Connecticut', 'Cardiology', 'In-network'),
#  (200342, 'BOWIE CARDIOLOGY', 'Connecticut', 'Cardiology', 'In-network'),
#  (200343, 'RUSSELLVILLE CARDIOLOGY', 'Connecticut', 'Cardiology', 'In-network'),
#  (200344, 'BUFFALO CARDIOLOGY', 'Connecticut', 'Cardiology', 'In-network'),
#  (200345, 'PLEASANTON DENTAL', 'Connecticut', 'Dental', 'In-network'),
#  (200346, 'ARNOLD DENTAL', 'Connecticut', 'Dental', 'In-network'),
#  (200347, 'ARVADA DENTAL', 'Connecticut', 'Dental', 'In-network'),
#  (200348, 'POST DERMATOLOGY', 'Connecticut', 'Dermatology', 'In-network'),
#  (200349, 'WILTON DERMATOLOGY', 'Connecticut', 'Dermatology', 'In-network'),
#  (200350, 'SOUTHAVEN DURABLE MEDICAL EQUIPMENT', 'Connecticut', 'Durable Medical Equipment', 'In-network'),
#  (200351, 'OVIEDO DURABLE MEDICAL EQUIPMENT', 'Connecticut', 'Durable Medical Equipment', 'In-network'),
#  (200352, 'ALSIP HOSPITAL', 'Connecticut', 'Hospital', 'In-network'),
#  (200353, 'NAPA HOSPITAL', 'Connecticut', 'Hospital', 'In-network'),
#  (200354, 'ALOHA HOSPITAL', 'Connecticut', 'Hospital', 'In-network'),
#  (200355, 'CENTRALIA HOSPITAL', 'Connecticut', 'Hospital', 'In-network'),
#  (200356, 'NORWOOD INTERNAL MEDICINE', 'Connecticut', 'Internal Medicine', 'In-network'),
#  (200357, 'VALLEY INTERNAL MEDICINE', 'Connecticut', 'Internal Medicine', 'In-network'),
#  (200358, 'WEIRTON INTERNAL MEDICINE', 'Connecticut', 'Internal Medicine', 'In-network'),
#  (200359, 'BOCA INTERNAL MEDICINE', 'Connecticut', 'Internal Medicine', 'Out-of-network'),
#  (200360, 'OKEMOS INTERNAL MEDICINE', 'Connecticut', 'Internal Medicine', 'In-network'),
#  (200361, 'BENTON NEUROLOGY', 'Connecticut', 'Neurology', 'In-network'),
#  (200362, 'WOODBRIDGE NEUROLOGY', 'Connecticut', 'Neurology', 'In-network'),
#  (200363, 'ROME NEUROLOGY', 'Connecticut', 'Neurology', 'In-network'),
#  (200364, 'KENDALL OBGYN', 'Connecticut', 'OBGYN', 'In-network'),
#  (200365, 'ALLAPATTAH ONCOLOGY', 'Connecticut', 'Oncology', 'In-network'),
#  (200366, 'SILVERDALE ONCOLOGY', 'Connecticut', 'Oncology', 'In-network'),
#  (200367, 'PERRYSBURG ONCOLOGY', 'Connecticut', 'Oncology', 'In-network'),
#  (200368, 'ELKRIDGE ONCOLOGY', 'Connecticut', 'Oncology', 'In-network'),
#  (200369, 'RICHFIELD ORTHODONTICS', 'Connecticut', 'Orthodontics', 'In-network'),
#  (200370, 'LOMBARD ORTHODONTICS', 'Connecticut', 'Orthodontics', 'In-network'),
#  (200371, 'PAHRUMP ORTHODONTICS', 'Connecticut', 'Orthodontics', 'In-network'),
#  (200372, 'BETHANY ORTHODONTICS', 'Connecticut', 'Orthodontics', 'In-network'),
#  (200373, 'PALMETTO PEDIATRICS', 'Connecticut', 'Pediatrics', 'In-network'),
#  (200374, 'POMONA PEDIATRICS', 'Connecticut', 'Pediatrics', 'In-network'),
#  (200375, 'LEISURE PEDIATRICS', 'Connecticut', 'Pediatrics', 'In-network'),
#  (200376, 'KALAMAZOO PEDIATRICS', 'Connecticut', 'Pediatrics', 'In-network'),
#  (200377, 'RUTHERFORD PEDIATRICS', 'Connecticut', 'Pediatrics', 'In-network'),
#  (200378, 'SOUTHBRIDGE PHYSICAL THERAPY', 'Connecticut', 'Physical Therapy', 'Out-of-network'),
#  (200379, 'HOBART PHYSICAL THERAPY', 'Connecticut', 'Physical Therapy', 'Out-of-network'),
#  (200380, 'THOMASVILLE PRIMARY CARE', 'Connecticut', 'Primary Care', 'In-network'),
#  (200381, 'WADSWORTH PRIMARY CARE', 'Connecticut', 'Primary Care', 'In-network'),
#  (200382, 'SMYRNA URGENT CARE', 'Connecticut', 'Urgent Care', 'In-network'),
#  (200383, 'INDEPENDENCE VISION', 'Connecticut', 'Vision', 'In-network'),
#  (200384, 'BENSENVILLE VISION', 'Connecticut', 'Vision', 'In-network'),
#  (200385, 'NIAGARA VISION', 'Connecticut', 'Vision', 'Out-of-network'),
#  (200386, 'WETHERSFIELD VISION', 'Connecticut', 'Vision', 'In-network'),
#  (200387, 'BALLENGER BEHAVIORAL HEALTH', 'Delaware', 'Behavioral Health', 'In-network'),
#  (200388, 'CASTRO BEHAVIORAL HEALTH', 'Delaware', 'Behavioral Health', 'In-network'),
#  (200389, 'CRAWFORDSVILLE BEHAVIORAL HEALTH', 'Delaware', 'Behavioral Health', 'In-network'),
#  (200390, 'ROUND CARDIOLOGY', 'Delaware', 'Cardiology', 'In-network'),
#  (200391, 'PITTSFIELD CARDIOLOGY', 'Delaware', 'Cardiology', 'In-network'),
#  (200392, 'WILLOUGHBY CARDIOLOGY', 'Delaware', 'Cardiology', 'In-network'),
#  (200393, 'KEARNS DENTAL', 'Delaware', 'Dental', 'In-network'),
#  (200394, 'SAND DENTAL', 'Delaware', 'Dental', 'In-network'),
#  (200395, 'FREMONT DENTAL', 'Delaware', 'Dental', 'In-network'),
#  (200396, 'AFFTON DERMATOLOGY', 'Delaware', 'Dermatology', 'In-network'),
#  (200397, 'MAPLE DERMATOLOGY', 'Delaware', 'Dermatology', 'In-network'),
#  (200398, 'FRAMINGHAM DERMATOLOGY', 'Delaware', 'Dermatology', 'Out-of-network'),
#  (200399, 'LUTZ DURABLE MEDICAL EQUIPMENT', 'Delaware', 'Durable Medical Equipment', 'In-network'),
#  (200400, 'CHICO DURABLE MEDICAL EQUIPMENT', 'Delaware', 'Durable Medical Equipment', 'In-network'),
#  (200401, 'SALT DURABLE MEDICAL EQUIPMENT', 'Delaware', 'Durable Medical Equipment', 'In-network'),
#  (200402, 'PEABODY HOSPITAL', 'Delaware', 'Hospital', 'In-network'),
#  (200403, 'SARATOGA HOSPITAL', 'Delaware', 'Hospital', 'In-network'),
#  (200404, 'RUTLAND HOSPITAL', 'Delaware', 'Hospital', 'In-network'),
#  (200405, 'LEAWOOD INTERNAL MEDICINE', 'Delaware', 'Internal Medicine', 'In-network'),
#  (200406, 'HALLANDALE NEUROLOGY', 'Delaware', 'Neurology', 'In-network'),
#  (200407, 'ALBANY NEUROLOGY', 'Delaware', 'Neurology', 'In-network'),
#  (200408, 'SEMINOLE OBGYN', 'Delaware', 'OBGYN', 'In-network'),
#  (200409, 'ROGERS OBGYN', 'Delaware', 'OBGYN', 'In-network'),
#  (200410, 'PEARL OBGYN', 'Delaware', 'OBGYN', 'In-network'),
#  (200411, 'WHEELING OBGYN', 'Delaware', 'OBGYN', 'In-network'),
#  (200412, 'COLUMBINE ONCOLOGY', 'Delaware', 'Oncology', 'In-network'),
#  (200413, 'HARKER ONCOLOGY', 'Delaware', 'Oncology', 'In-network'),
#  (200414, 'CERES ORTHODONTICS', 'Delaware', 'Orthodontics', 'In-network'),
#  (200415, 'ESTELLE ORTHODONTICS', 'Delaware', 'Orthodontics', 'In-network'),
#  (200416, 'HOLIDAY ORTHODONTICS', 'Delaware', 'Orthodontics', 'In-network'),
#  (200417, 'GREER PEDIATRICS', 'Delaware', 'Pediatrics', 'In-network'),
#  (200418, 'CHARLESTON PEDIATRICS', 'Delaware', 'Pediatrics', 'In-network'),
#  (200419, 'HOLTSVILLE PEDIATRICS', 'Delaware', 'Pediatrics', 'In-network'),
#  (200420, 'PENNSAUKEN PHYSICAL THERAPY', 'Delaware', 'Physical Therapy', 'Out-of-network'),
#  (200421, 'WADSWORTH PHYSICAL THERAPY', 'Delaware', 'Physical Therapy', 'In-network'),
#  (200422, 'DESERT PRIMARY CARE', 'Delaware', 'Primary Care', 'Out-of-network'),
#  (200423, 'TOPEKA PRIMARY CARE', 'Delaware', 'Primary Care', 'In-network'),
#  (200424, 'ST. URGENT CARE', 'Delaware', 'Urgent Care', 'In-network'),
#  (200425, 'MAULDIN URGENT CARE', 'Delaware', 'Urgent Care', 'In-network'),
#  (200426, 'AMERICAN URGENT CARE', 'Delaware', 'Urgent Care', 'In-network'),
#  (200427, 'PORTAGE VISION', 'Delaware', 'Vision', 'In-network'),
#  (200428, 'CALDWELL VISION', 'Delaware', 'Vision', 'In-network'),
#  (200429, 'GOSHEN BEHAVIORAL HEALTH', 'Florida', 'Behavioral Health', 'In-network'),
#  (200430, 'LOMA BEHAVIORAL HEALTH', 'Florida', 'Behavioral Health', 'In-network'),
#  (200431, 'GRAHAM BEHAVIORAL HEALTH', 'Florida', 'Behavioral Health', 'In-network'),
#  (200432, 'DENISON BEHAVIORAL HEALTH', 'Florida', 'Behavioral Health', 'In-network'),
#  (200433, 'SIOUX BEHAVIORAL HEALTH', 'Florida', 'Behavioral Health', 'In-network'),
#  (200434, 'MANDAN CARDIOLOGY', 'Florida', 'Cardiology', 'In-network'),
#  (200435, 'HOMER CARDIOLOGY', 'Florida', 'Cardiology', 'In-network'),
#  (200436, 'NORTHAMPTON DENTAL', 'Florida', 'Dental', 'In-network'),
#  (200437, 'PORTLAND DENTAL', 'Florida', 'Dental', 'Out-of-network'),
#  (200438, 'KINGSTON DENTAL', 'Florida', 'Dental', 'In-network'),
#  (200439, 'CAROL DERMATOLOGY', 'Florida', 'Dermatology', 'In-network'),
#  (200440, 'FLOWING DERMATOLOGY', 'Florida', 'Dermatology', 'Out-of-network'),
#  (200441, 'BANGOR DERMATOLOGY', 'Florida', 'Dermatology', 'In-network'),
#  (200442, 'MASON DERMATOLOGY', 'Florida', 'Dermatology', 'In-network'),
#  (200443, 'LAYTON DURABLE MEDICAL EQUIPMENT', 'Florida', 'Durable Medical Equipment', 'In-network'),
#  (200444, 'SWANSEA DURABLE MEDICAL EQUIPMENT', 'Florida', 'Durable Medical Equipment', 'In-network'),
#  (200445, 'OAKVILLE HOSPITAL', 'Florida', 'Hospital', 'In-network'),
#  (200446, 'ALAFAYA HOSPITAL', 'Florida', 'Hospital', 'In-network'),
#  (200447, 'BETHEL HOSPITAL', 'Florida', 'Hospital', 'In-network'),
#  (200448, 'HOBBS HOSPITAL', 'Florida', 'Hospital', 'In-network'),
#  (200449, 'COVINA INTERNAL MEDICINE', 'Florida', 'Internal Medicine', 'In-network'),
#  (200450, 'BOWIE INTERNAL MEDICINE', 'Florida', 'Internal Medicine', 'In-network'),
#  (200451, 'HARKER INTERNAL MEDICINE', 'Florida', 'Internal Medicine', 'In-network'),
#  (200452, 'LOMA INTERNAL MEDICINE', 'Florida', 'Internal Medicine', 'In-network'),
#  (200453, 'MERCED NEUROLOGY', 'Florida', 'Neurology', 'Out-of-network'),
#  (200454, 'DERBY NEUROLOGY', 'Florida', 'Neurology', 'In-network'),
#  (200455, 'UNIONDALE NEUROLOGY', 'Florida', 'Neurology', 'In-network'),
#  (200456, 'GOOSE NEUROLOGY', 'Florida', 'Neurology', 'In-network'),
#  (200457, 'ATLANTA OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200458, 'CLINTON OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200459, 'BOZEMAN OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200460, 'BOLINGBROOK OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200461, 'BOLINGBROOK OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200462, 'ROME OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200463, 'CLIFFSIDE OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200464, 'FLOWING OBGYN', 'Florida', 'OBGYN', 'In-network'),
#  (200465, 'WESTFORD ONCOLOGY', 'Florida', 'Oncology', 'In-network'),
#  (200466, 'MILLEDGEVILLE ORTHODONTICS', 'Florida', 'Orthodontics', 'In-network'),
#  (200467, 'HUEYTOWN ORTHODONTICS', 'Florida', 'Orthodontics', 'In-network'),
#  (200468, 'POST ORTHODONTICS', 'Florida', 'Orthodontics', 'In-network'),
#  (200469, 'HIGHLANDS PEDIATRICS', 'Florida', 'Pediatrics', 'Out-of-network'),
#  (200470, 'INVER PEDIATRICS', 'Florida', 'Pediatrics', 'In-network'),
#  (200471, 'LAFAYETTE PEDIATRICS', 'Florida', 'Pediatrics', 'In-network'),
#  (200472, 'PARADISE PEDIATRICS', 'Florida', 'Pediatrics', 'In-network'),
#  (200473, 'GLEN PHYSICAL THERAPY', 'Florida', 'Physical Therapy', 'In-network'),
#  (200474, 'MOORE PHYSICAL THERAPY', 'Florida', 'Physical Therapy', 'In-network'),
#  (200475, 'FRESNO PHYSICAL THERAPY', 'Florida', 'Physical Therapy', 'Out-of-network'),
#  (200476, 'SAFETY PHYSICAL THERAPY', 'Florida', 'Physical Therapy', 'Out-of-network'),
#  (200477, 'CATHEDRAL PRIMARY CARE', 'Florida', 'Primary Care', 'In-network'),
#  (200478, 'MERRILLVILLE PRIMARY CARE', 'Florida', 'Primary Care', 'In-network'),
#  (200479, 'AMERICAN PRIMARY CARE', 'Florida', 'Primary Care', 'In-network'),
#  (200480, 'REDWOOD URGENT CARE', 'Florida', 'Urgent Care', 'In-network'),
#  (200481, 'HOLDEN URGENT CARE', 'Florida', 'Urgent Care', 'In-network'),
#  (200482, 'WESTMINSTER URGENT CARE', 'Florida', 'Urgent Care', 'In-network'),
#  (200483, 'DENTON URGENT CARE', 'Florida', 'Urgent Care', 'In-network'),
#  (200484, 'PARMA VISION', 'Florida', 'Vision', 'In-network'),
#  (200485, 'NOVATO VISION', 'Florida', 'Vision', 'In-network'),
#  (200486, 'WOODSTOCK VISION', 'Florida', 'Vision', 'In-network'),
#  (200487, 'GARLAND VISION', 'Florida', 'Vision', 'In-network'),
#  (200488, 'CASTLE VISION', 'Florida', 'Vision', 'In-network'),
#  (200489, 'CHESTERFIELD BEHAVIORAL HEALTH', 'Georgia', 'Behavioral Health', 'In-network'),
#  (200490, 'SHOREVIEW BEHAVIORAL HEALTH', 'Georgia', 'Behavioral Health', 'In-network'),
#  (200491, 'HURST CARDIOLOGY', 'Georgia', 'Cardiology', 'Out-of-network'),
#  (200492, 'HILO CARDIOLOGY', 'Georgia', 'Cardiology', 'In-network'),
#  (200493, 'GOODLETTSVILLE CARDIOLOGY', 'Georgia', 'Cardiology', 'In-network'),
#  (200494, 'CHICAGO CARDIOLOGY', 'Georgia', 'Cardiology', 'In-network'),
#  (200495, 'RADCLIFF DENTAL', 'Georgia', 'Dental', 'In-network'),
#  (200496, 'STONEHAM DERMATOLOGY', 'Georgia', 'Dermatology', 'In-network'),
#  (200497, 'SAFETY DERMATOLOGY', 'Georgia', 'Dermatology', 'In-network'),
#  (200498, 'PLAINVIEW DURABLE MEDICAL EQUIPMENT', 'Georgia', 'Durable Medical Equipment', 'In-network'),
#  (200499, 'GATESVILLE DURABLE MEDICAL EQUIPMENT', 'Georgia', 'Durable Medical Equipment', 'In-network'),
#  (200500, 'PARKLAND HOSPITAL', 'Georgia', 'Hospital', 'In-network'),
#  (200501, 'PONCA HOSPITAL', 'Georgia', 'Hospital', 'In-network'),
#  (200502, 'MURFREESBORO HOSPITAL', 'Georgia', 'Hospital', 'In-network'),
#  (200503, 'BARTLETT INTERNAL MEDICINE', 'Georgia', 'Internal Medicine', 'In-network'),
#  (200504, 'MARIETTA INTERNAL MEDICINE', 'Georgia', 'Internal Medicine', 'In-network'),
#  (200505, 'HARRISON INTERNAL MEDICINE', 'Georgia', 'Internal Medicine', 'In-network'),
#  (200506, 'WOODBRIDGE NEUROLOGY', 'Georgia', 'Neurology', 'In-network'),
#  (200507, 'HOMEWOOD NEUROLOGY', 'Georgia', 'Neurology', 'In-network'),
#  (200508, 'KANKAKEE NEUROLOGY', 'Georgia', 'Neurology', 'In-network'),
#  (200509, 'MOUNTLAKE OBGYN', 'Georgia', 'OBGYN', 'In-network'),
#  (200510, 'GOODINGS OBGYN', 'Georgia', 'OBGYN', 'In-network'),
#  (200511, 'CASTAIC ONCOLOGY', 'Georgia', 'Oncology', 'In-network'),
#  (200512, 'LEMAY ONCOLOGY', 'Georgia', 'Oncology', 'Out-of-network'),
#  (200513, 'MARTHA ONCOLOGY', 'Georgia', 'Oncology', 'In-network'),
#  (200514, 'MAMARONECK ONCOLOGY', 'Georgia', 'Oncology', 'Out-of-network'),
#  (200515, 'MIDDLETON ONCOLOGY', 'Georgia', 'Oncology', 'Out-of-network'),
#  (200516, 'EUCLID ORTHODONTICS', 'Georgia', 'Orthodontics', 'In-network'),
#  (200517, 'MILTON ORTHODONTICS', 'Georgia', 'Orthodontics', 'In-network'),
#  (200518, 'HANOVER PEDIATRICS', 'Georgia', 'Pediatrics', 'In-network'),
#  (200519, 'LAKEVILLE PHYSICAL THERAPY', 'Georgia', 'Physical Therapy', 'In-network'),
#  (200520, 'WHEAT PRIMARY CARE', 'Georgia', 'Primary Care', 'In-network'),
#  (200521, 'JACKSON PRIMARY CARE', 'Georgia', 'Primary Care', 'In-network'),
#  (200522, 'MAKAKILO URGENT CARE', 'Georgia', 'Urgent Care', 'In-network'),
#  (200523, 'UNIONDALE URGENT CARE', 'Georgia', 'Urgent Care', 'In-network'),
#  (200524, 'WATERLOO URGENT CARE', 'Georgia', 'Urgent Care', 'In-network'),
#  (200525, 'DAYTON URGENT CARE', 'Georgia', 'Urgent Care', 'In-network'),
#  (200526, 'ALAMO VISION', 'Georgia', 'Vision', 'In-network'),
#  (200527, 'PLANT VISION', 'Georgia', 'Vision', 'In-network'),
#  (200528, 'BOSTONIA VISION', 'Georgia', 'Vision', 'In-network'),
#  (200529, 'TALLMADGE BEHAVIORAL HEALTH', 'Hawaii', 'Behavioral Health', 'In-network'),
#  (200530, 'DEDHAM BEHAVIORAL HEALTH', 'Hawaii', 'Behavioral Health', 'Out-of-network'),
#  (200531, 'BENTON CARDIOLOGY', 'Hawaii', 'Cardiology', 'In-network'),
#  (200532, 'CAMDEN DENTAL', 'Hawaii', 'Dental', 'In-network'),
#  (200533, 'ROCKLEDGE DERMATOLOGY', 'Hawaii', 'Dermatology', 'In-network'),
#  (200534, 'GREATER DURABLE MEDICAL EQUIPMENT', 'Hawaii', 'Durable Medical Equipment', 'In-network'),
#  (200535, 'CHANHASSEN HOSPITAL', 'Hawaii', 'Hospital', 'In-network'),
#  (200536, 'BRIDGEPORT HOSPITAL', 'Hawaii', 'Hospital', 'In-network'),
#  (200537, 'WOBURN INTERNAL MEDICINE', 'Hawaii', 'Internal Medicine', 'In-network'),
#  (200538, 'FAIRHOPE NEUROLOGY', 'Hawaii', 'Neurology', 'In-network'),
#  (200539, 'KERNERSVILLE OBGYN', 'Hawaii', 'OBGYN', 'In-network'),
#  (200540, 'GROVE ONCOLOGY', 'Hawaii', 'Oncology', 'Out-of-network'),
#  (200541, 'BRIGHAM ORTHODONTICS', 'Hawaii', 'Orthodontics', 'Out-of-network'),
#  (200542, 'COPPELL PEDIATRICS', 'Hawaii', 'Pediatrics', 'In-network'),
#  (200543, 'NAVARRE PHYSICAL THERAPY', 'Hawaii', 'Physical Therapy', 'In-network'),
#  (200544, 'SPOKANE PRIMARY CARE', 'Hawaii', 'Primary Care', 'In-network'),
#  (200545, 'CASA URGENT CARE', 'Hawaii', 'Urgent Care', 'In-network'),
#  (200546, 'HUNTERSVILLE VISION', 'Hawaii', 'Vision', 'In-network'),
#  (200547, 'GREER VISION', 'Hawaii', 'Vision', 'In-network'),
#  (200548, 'AMERICAN BEHAVIORAL HEALTH', 'Idaho', 'Behavioral Health', 'In-network'),
#  (200549, 'LEMAY CARDIOLOGY', 'Idaho', 'Cardiology', 'In-network'),
#  (200550, 'TUALATIN CARDIOLOGY', 'Idaho', 'Cardiology', 'In-network'),
#  (200551, 'CLEMMONS DENTAL', 'Idaho', 'Dental', 'In-network'),
#  (200552, 'HIBBING DERMATOLOGY', 'Idaho', 'Dermatology', 'In-network'),
#  (200553, 'TARPON DURABLE MEDICAL EQUIPMENT', 'Idaho', 'Durable Medical Equipment', 'In-network'),
#  (200554, 'SHOREWOOD HOSPITAL', 'Idaho', 'Hospital', 'Out-of-network'),
#  (200555, 'NICHOLASVILLE HOSPITAL', 'Idaho', 'Hospital', 'In-network'),
#  (200556, 'LANGLEY INTERNAL MEDICINE', 'Idaho', 'Internal Medicine', 'In-network'),
#  (200557, 'WHEAT NEUROLOGY', 'Idaho', 'Neurology', 'In-network'),
#  (200558, 'DUBUQUE OBGYN', 'Idaho', 'OBGYN', 'In-network'),
#  (200559, 'BRISTOL ONCOLOGY', 'Idaho', 'Oncology', 'In-network'),
#  (200560, 'PRICHARD ORTHODONTICS', 'Idaho', 'Orthodontics', 'Out-of-network'),
#  (200561, 'CIMARRON PEDIATRICS', 'Idaho', 'Pediatrics', 'In-network'),
#  (200562, 'JOHNS PHYSICAL THERAPY', 'Idaho', 'Physical Therapy', 'In-network'),
#  (200563, 'POUGHKEEPSIE PRIMARY CARE', 'Idaho', 'Primary Care', 'In-network'),
#  (200564, 'HAMILTON URGENT CARE', 'Idaho', 'Urgent Care', 'In-network'),
#  (200565, 'STUART VISION', 'Idaho', 'Vision', 'In-network'),
#  (200566, 'ELGIN BEHAVIORAL HEALTH', 'Illinois', 'Behavioral Health', 'In-network'),
#  (200567, 'PARK BEHAVIORAL HEALTH', 'Illinois', 'Behavioral Health', 'In-network'),
#  (200568, 'YORK BEHAVIORAL HEALTH', 'Illinois', 'Behavioral Health', 'Out-of-network'),
#  (200569, 'LARGO CARDIOLOGY', 'Illinois', 'Cardiology', 'Out-of-network'),
#  (200570, 'SPANISH CARDIOLOGY', 'Illinois', 'Cardiology', 'In-network'),
#  (200571, 'SAUGUS CARDIOLOGY', 'Illinois', 'Cardiology', 'In-network'),
#  (200572, 'STEVENS CARDIOLOGY', 'Illinois', 'Cardiology', 'In-network'),
#  (200573, 'KINSTON DENTAL', 'Illinois', 'Dental', 'In-network'),
#  (200574, 'SHERRELWOOD DENTAL', 'Illinois', 'Dental', 'In-network'),
#  (200575, 'LYNDHURST DENTAL', 'Illinois', 'Dental', 'In-network'),
#  (200576, 'GALVESTON DENTAL', 'Illinois', 'Dental', 'Out-of-network'),
#  (200577, 'JOHNSON DERMATOLOGY', 'Illinois', 'Dermatology', 'In-network'),
#  (200578, 'RIO DERMATOLOGY', 'Illinois', 'Dermatology', 'Out-of-network'),
#  (200579, 'TRENTON DERMATOLOGY', 'Illinois', 'Dermatology', 'In-network'),
#  (200580, 'LIBERAL DURABLE MEDICAL EQUIPMENT', 'Illinois', 'Durable Medical Equipment', 'In-network'),
#  (200581, 'TWINSBURG DURABLE MEDICAL EQUIPMENT', 'Illinois', 'Durable Medical Equipment', 'In-network'),
#  (200582, 'BELLWOOD DURABLE MEDICAL EQUIPMENT', 'Illinois', 'Durable Medical Equipment', 'In-network'),
#  (200583, 'JEFFERSONTOWN DURABLE MEDICAL EQUIPMENT', 'Illinois', 'Durable Medical Equipment', 'In-network'),
#  (200584, 'LEHI DURABLE MEDICAL EQUIPMENT', 'Illinois', 'Durable Medical Equipment', 'In-network'),
#  (200585, 'RAMSEY HOSPITAL', 'Illinois', 'Hospital', 'In-network'),
#  (200586, 'ROUND INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200587, 'MITCHELL INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200588, 'MITCHELL INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'Out-of-network'),
#  (200589, 'ALGONQUIN INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200590, 'AMSTERDAM INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200591, 'IMMOKALEE INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200592, 'LEAWOOD INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200593, 'ALAMOGORDO INTERNAL MEDICINE', 'Illinois', 'Internal Medicine', 'In-network'),
#  (200594, 'COLCHESTER NEUROLOGY', 'Illinois', 'Neurology', 'In-network'),
#  (200595, 'WILSON NEUROLOGY', 'Illinois', 'Neurology', 'In-network'),
#  (200596, 'ASHEVILLE NEUROLOGY', 'Illinois', 'Neurology', 'In-network'),
#  (200597, 'TRACY NEUROLOGY', 'Illinois', 'Neurology', 'In-network'),
#  (200598, 'KENOSHA OBGYN', 'Illinois', 'OBGYN', 'In-network'),
#  (200599, 'YORK OBGYN', 'Illinois', 'OBGYN', 'Out-of-network'),
#  (200600, 'PARKER ONCOLOGY', 'Illinois', 'Oncology', 'In-network'),
#  (200601, 'GOOSE ONCOLOGY', 'Illinois', 'Oncology', 'In-network'),
#  (200602, 'SILOAM ONCOLOGY', 'Illinois', 'Oncology', 'In-network'),
#  (200603, 'KETTERING ONCOLOGY', 'Illinois', 'Oncology', 'In-network'),
#  (200604, 'BOWLING ONCOLOGY', 'Illinois', 'Oncology', 'Out-of-network'),
#  (200605, 'LAUDERDALE ORTHODONTICS', 'Illinois', 'Orthodontics', 'In-network'),
#  (200606, 'DAMASCUS ORTHODONTICS', 'Illinois', 'Orthodontics', 'In-network'),
#  (200607, 'ANTHEM ORTHODONTICS', 'Illinois', 'Orthodontics', 'Out-of-network'),
#  (200608, 'PRATTVILLE ORTHODONTICS', 'Illinois', 'Orthodontics', 'In-network'),
#  (200609, 'LANSING PEDIATRICS', 'Illinois', 'Pediatrics', 'In-network'),
#  (200610, 'ENGLEWOOD PEDIATRICS', 'Illinois', 'Pediatrics', 'In-network'),
#  (200611, 'BAYONET PEDIATRICS', 'Illinois', 'Pediatrics', 'In-network'),
#  (200612, 'PROVO PEDIATRICS', 'Illinois', 'Pediatrics', 'In-network'),
#  (200613, 'BETHLEHEM PEDIATRICS', 'Illinois', 'Pediatrics', 'In-network'),
#  (200614, 'DOLTON PHYSICAL THERAPY', 'Illinois', 'Physical Therapy', 'In-network'),
#  (200615, 'MOUNTAIN PHYSICAL THERAPY', 'Illinois', 'Physical Therapy', 'In-network'),
#  (200616, 'BELLA PHYSICAL THERAPY', 'Illinois', 'Physical Therapy', 'In-network'),
#  (200617, 'OAKLAND PRIMARY CARE', 'Illinois', 'Primary Care', 'In-network'),
#  (200618, 'COMMERCE PRIMARY CARE', 'Illinois', 'Primary Care', 'Out-of-network'),
#  (200619, 'ROLLA PRIMARY CARE', 'Illinois', 'Primary Care', 'In-network'),
#  (200620, 'CARSON PRIMARY CARE', 'Illinois', 'Primary Care', 'In-network'),
#  (200621, 'GRANTS URGENT CARE', 'Illinois', 'Urgent Care', 'In-network'),
#  (200622, 'ATLANTIC URGENT CARE', 'Illinois', 'Urgent Care', 'In-network'),
#  (200623, 'HOBBS URGENT CARE', 'Illinois', 'Urgent Care', 'In-network'),
#  (200624, 'DEPEW URGENT CARE', 'Illinois', 'Urgent Care', 'In-network'),
# ...
#  (200788, 'LOCKPORT CARDIOLOGY', 'Louisiana', 'Cardiology', 'In-network'),
#  (200789, 'SPRING DENTAL', 'Louisiana', 'Dental', 'In-network'),
#  (200790, 'FORREST DERMATOLOGY', 'Louisiana', 'Dermatology', 'In-network'),
#  (200791, 'RIDGELAND DERMATOLOGY', 'Louisiana', 'Dermatology', 'In-network'),
#  (200792, 'PINECREST DURABLE MEDICAL EQUIPMENT', 'Louisiana', 'Durable Medical Equipment', 'In-network'),
#  (200793, 'RENO HOSPITAL', 'Louisiana', 'Hospital', 'In-network'),
#  (200794, 'BAYSIDE HOSPITAL', 'Louisiana', 'Hospital', 'In-network'),
#  (200795, 'GADSDEN HOSPITAL', 'Louisiana', 'Hospital', 'In-network'),
#  (200796, 'EDEN INTERNAL MEDICINE', 'Louisiana', 'Internal Medicine', 'In-network'),
#  (200797, 'JUNCTION INTERNAL MEDICINE', 'Louisiana', 'Internal Medicine', 'Out-of-network'),
#  (200798, 'PADUCAH INTERNAL MEDICINE', 'Louisiana', 'Internal Medicine', 'In-network'),
#  (200799, 'BRIGHAM NEUROLOGY', 'Louisiana', 'Neurology', 'In-network'),
#  (200800, 'HILLSBORO OBGYN', 'Louisiana', 'OBGYN', 'In-network'),
#  (200801, 'MOORPARK OBGYN', 'Louisiana', 'OBGYN', 'In-network'),
#  (200802, 'LACONIA ONCOLOGY', 'Louisiana', 'Oncology', 'In-network'),
#  (200803, 'ABINGTON ORTHODONTICS', 'Louisiana', 'Orthodontics', 'In-network'),
#  (200804, 'SULPHUR ORTHODONTICS', 'Louisiana', 'Orthodontics', 'In-network'),
#  (200805, 'MIDDLEBURG PEDIATRICS', 'Louisiana', 'Pediatrics', 'In-network'),
#  (200806, 'WALTHAM PEDIATRICS', 'Louisiana', 'Pediatrics', 'In-network'),
#  (200807, 'ROCKY PEDIATRICS', 'Louisiana', 'Pediatrics', 'In-network'),
#  (200808, 'FULLERTON PHYSICAL THERAPY', 'Louisiana', 'Physical Therapy', 'In-network'),
#  (200809, 'DUNCAN PHYSICAL THERAPY', 'Louisiana', 'Physical Therapy', 'Out-of-network'),
#  (200810, 'HIGHLANDS PRIMARY CARE', 'Louisiana', 'Primary Care', 'In-network'),
#  (200811, 'BIRMINGHAM PRIMARY CARE', 'Louisiana', 'Primary Care', 'In-network'),
#  (200812, 'PALMER URGENT CARE', 'Louisiana', 'Urgent Care', 'In-network'),
#  (200813, 'RUSSELLVILLE URGENT CARE', 'Louisiana', 'Urgent Care', 'In-network'),
#  (200814, 'BRUSHY VISION', 'Louisiana', 'Vision', 'In-network'),
#  (200815, 'HIALEAH VISION', 'Louisiana', 'Vision', 'In-network'),
#  (200816, 'SCHOFIELD VISION', 'Louisiana', 'Vision', 'In-network'),
#  (200817, 'GARDEN BEHAVIORAL HEALTH', 'Maine', 'Behavioral Health', 'In-network'),
#  (200818, 'LARAMIE BEHAVIORAL HEALTH', 'Maine', 'Behavioral Health', 'Out-of-network'),
#  (200819, 'SAGINAW CARDIOLOGY', 'Maine', 'Cardiology', 'In-network'),
#  (200820, 'HIGHVIEW CARDIOLOGY', 'Maine', 'Cardiology', 'In-network'),
#  (200821, 'NORTHAMPTON CARDIOLOGY', 'Maine', 'Cardiology', 'In-network'),
#  (200822, 'CRYSTAL CARDIOLOGY', 'Maine', 'Cardiology', 'Out-of-network'),
#  (200823, 'DANVERS CARDIOLOGY', 'Maine', 'Cardiology', 'In-network'),
#  (200824, 'FAIRFIELD DENTAL', 'Maine', 'Dental', 'In-network'),
#  (200825, 'CHEEKTOWAGA DENTAL', 'Maine', 'Dental', 'In-network'),
#  (200826, 'CRANFORD DENTAL', 'Maine', 'Dental', 'In-network'),
#  (200827, 'AGAWAM DENTAL', 'Maine', 'Dental', 'Out-of-network'),
#  (200828, 'SALEM DENTAL', 'Maine', 'Dental', 'In-network'),
#  (200829, 'GENEVA DENTAL', 'Maine', 'Dental', 'In-network'),
#  (200830, 'BRUNSWICK DERMATOLOGY', 'Maine', 'Dermatology', 'Out-of-network'),
#  (200831, 'MCKINLEYVILLE DERMATOLOGY', 'Maine', 'Dermatology', 'In-network'),
#  (200832, 'BRAINTREE DERMATOLOGY', 'Maine', 'Dermatology', 'In-network'),
#  (200833, 'NORTHFIELD DERMATOLOGY', 'Maine', 'Dermatology', 'In-network'),
#  (200834, 'CHESTER DURABLE MEDICAL EQUIPMENT', 'Maine', 'Durable Medical Equipment', 'In-network'),
#  (200835, 'BREMERTON DURABLE MEDICAL EQUIPMENT', 'Maine', 'Durable Medical Equipment', 'In-network'),
#  (200836, 'TAKOMA DURABLE MEDICAL EQUIPMENT', 'Maine', 'Durable Medical Equipment', 'In-network'),
#  (200837, 'FLORISSANT DURABLE MEDICAL EQUIPMENT', 'Maine', 'Durable Medical Equipment', 'In-network'),
#  (200838, 'CRYSTAL HOSPITAL', 'Maine', 'Hospital', 'In-network'),
#  (200839, 'OAKVILLE HOSPITAL', 'Maine', 'Hospital', 'In-network'),
#  (200840, 'HUNT HOSPITAL', 'Maine', 'Hospital', 'In-network'),
#  (200841, 'RAYTOWN HOSPITAL', 'Maine', 'Hospital', 'In-network'),
#  (200842, 'WESTERVILLE INTERNAL MEDICINE', 'Maine', 'Internal Medicine', 'In-network'),
#  (200843, 'IRVINGTON INTERNAL MEDICINE', 'Maine', 'Internal Medicine', 'In-network'),
#  (200844, 'MEAD INTERNAL MEDICINE', 'Maine', 'Internal Medicine', 'In-network'),
#  (200845, 'DULUTH INTERNAL MEDICINE', 'Maine', 'Internal Medicine', 'In-network'),
#  (200846, 'REDLAND INTERNAL MEDICINE', 'Maine', 'Internal Medicine', 'In-network'),
#  (200847, 'YARMOUTH INTERNAL MEDICINE', 'Maine', 'Internal Medicine', 'In-network'),
#  (200848, 'TIFTON NEUROLOGY', 'Maine', 'Neurology', 'In-network'),
#  (200849, 'IRVINE NEUROLOGY', 'Maine', 'Neurology', 'In-network'),
#  (200850, 'LINCOLN NEUROLOGY', 'Maine', 'Neurology', 'In-network'),
#  (200851, 'BESSEMER NEUROLOGY', 'Maine', 'Neurology', 'In-network'),
#  (200852, 'GRAPEVINE OBGYN', 'Maine', 'OBGYN', 'In-network'),
#  (200853, 'BAYSHORE OBGYN', 'Maine', 'OBGYN', 'In-network'),
#  (200854, 'KERNERSVILLE OBGYN', 'Maine', 'OBGYN', 'In-network'),
#  (200855, 'BELLAIRE OBGYN', 'Maine', 'OBGYN', 'In-network'),
#  (200856, 'MANKATO OBGYN', 'Maine', 'OBGYN', 'Out-of-network'),
#  (200857, 'BROOKINGS OBGYN', 'Maine', 'OBGYN', 'In-network'),
#  (200858, 'CARSON ONCOLOGY', 'Maine', 'Oncology', 'Out-of-network'),
#  (200859, 'DENVER ONCOLOGY', 'Maine', 'Oncology', 'In-network'),
#  (200860, 'HOUMA ONCOLOGY', 'Maine', 'Oncology', 'Out-of-network'),
#  (200861, 'PASSAIC ONCOLOGY', 'Maine', 'Oncology', 'Out-of-network'),
#  (200862, 'ENCHANTED ONCOLOGY', 'Maine', 'Oncology', 'Out-of-network'),
#  (200863, 'TUSCALOOSA ORTHODONTICS', 'Maine', 'Orthodontics', 'In-network'),
#  (200864, 'SHREVEPORT ORTHODONTICS', 'Maine', 'Orthodontics', 'In-network'),
#  (200865, 'MARTINEZ ORTHODONTICS', 'Maine', 'Orthodontics', 'In-network'),
#  (200866, 'PEMBROKE PEDIATRICS', 'Maine', 'Pediatrics', 'In-network'),
#  (200867, 'ROANOKE PEDIATRICS', 'Maine', 'Pediatrics', 'In-network'),
#  (200868, 'FLORIN PHYSICAL THERAPY', 'Maine', 'Physical Therapy', 'In-network'),
#  (200869, 'AMARILLO PHYSICAL THERAPY', 'Maine', 'Physical Therapy', 'In-network'),
#  (200870, 'SANTA PHYSICAL THERAPY', 'Maine', 'Physical Therapy', 'In-network'),
#  (200871, 'CITRUS PHYSICAL THERAPY', 'Maine', 'Physical Therapy', 'In-network'),
#  (200872, 'CATALINA PRIMARY CARE', 'Maine', 'Primary Care', 'In-network'),
#  (200873, 'RICHFIELD PRIMARY CARE', 'Maine', 'Primary Care', 'In-network'),
#  (200874, 'FAIRLAND PRIMARY CARE', 'Maine', 'Primary Care', 'Out-of-network'),
#  (200875, 'UNIVERSAL PRIMARY CARE', 'Maine', 'Primary Care', 'In-network'),
#  (200876, 'GOODYEAR PRIMARY CARE', 'Maine', 'Primary Care', 'In-network'),
#  (200877, 'PRUNEDALE PRIMARY CARE', 'Maine', 'Primary Care', 'In-network'),
#  (200878, 'SAYREVILLE URGENT CARE', 'Maine', 'Urgent Care', 'In-network'),
#  (200879, 'CONEY URGENT CARE', 'Maine', 'Urgent Care', 'Out-of-network'),
#  (200880, 'ALICE URGENT CARE', 'Maine', 'Urgent Care', 'In-network'),
#  (200881, 'KENDALL URGENT CARE', 'Maine', 'Urgent Care', 'In-network'),
#  (200882, 'HILLSBORO VISION', 'Maine', 'Vision', 'In-network'),
#  (200883, 'DUNWOODY VISION', 'Maine', 'Vision', 'In-network'),
#  (200884, 'FLOWER VISION', 'Maine', 'Vision', 'In-network'),
#  (200885, 'PICO VISION', 'Maine', 'Vision', 'Out-of-network'),
#  (200886, 'TEANECK VISION', 'Maine', 'Vision', 'In-network'),
#  (200887, 'CULVER BEHAVIORAL HEALTH', 'Maryland', 'Behavioral Health', 'In-network'),
#  (200888, 'HAZLETON BEHAVIORAL HEALTH', 'Maryland', 'Behavioral Health', 'Out-of-network'),
#  (200889, 'YORKVILLE BEHAVIORAL HEALTH', 'Maryland', 'Behavioral Health', 'In-network'),
#  (200890, 'WEST CARDIOLOGY', 'Maryland', 'Cardiology', 'In-network'),
#  (200891, 'ESTELLE CARDIOLOGY', 'Maryland', 'Cardiology', 'In-network'),
#  (200892, 'TIFFIN CARDIOLOGY', 'Maryland', 'Cardiology', 'In-network'),
#  (200893, 'AGOURA CARDIOLOGY', 'Maryland', 'Cardiology', 'In-network'),
#  (200894, 'CENTEREACH CARDIOLOGY', 'Maryland', 'Cardiology', 'In-network'),
#  (200895, 'CARMICHAEL CARDIOLOGY', 'Maryland', 'Cardiology', 'In-network'),
#  (200896, 'LEWISTON DENTAL', 'Maryland', 'Dental', 'In-network'),
#  (200897, 'TONAWANDA DENTAL', 'Maryland', 'Dental', 'In-network'),
#  (200898, 'CONCORD DENTAL', 'Maryland', 'Dental', 'In-network'),
#  (200899, 'RICHLAND DENTAL', 'Maryland', 'Dental', 'In-network'),
#  (200900, 'FLAGSTAFF DENTAL', 'Maryland', 'Dental', 'In-network'),
#  (200901, 'COLLIERVILLE DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200902, 'HORIZON DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200903, 'LINDENHURST DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200904, 'CATHEDRAL DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200905, 'APOPKA DERMATOLOGY', 'Maryland', 'Dermatology', 'Out-of-network'),
#  (200906, 'POMONA DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200907, 'CHICKASHA DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200908, 'MEHLVILLE DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200909, 'POPLAR DERMATOLOGY', 'Maryland', 'Dermatology', 'In-network'),
#  (200910, 'TINTON DURABLE MEDICAL EQUIPMENT', 'Maryland', 'Durable Medical Equipment', 'In-network'),
#  (200911, 'ELMWOOD DURABLE MEDICAL EQUIPMENT', 'Maryland', 'Durable Medical Equipment', 'In-network'),
#  (200912, 'HERMISTON HOSPITAL', 'Maryland', 'Hospital', 'In-network'),
#  (200913, 'MUSKEGO HOSPITAL', 'Maryland', 'Hospital', 'In-network'),
#  (200914, 'BLOOMFIELD HOSPITAL', 'Maryland', 'Hospital', 'In-network'),
#  (200915, 'CORVALLIS HOSPITAL', 'Maryland', 'Hospital', 'In-network'),
#  (200916, 'POCATELLO HOSPITAL', 'Maryland', 'Hospital', 'In-network'),
#  (200917, 'GREENSBORO INTERNAL MEDICINE', 'Maryland', 'Internal Medicine', 'In-network'),
#  (200918, 'KAYSVILLE INTERNAL MEDICINE', 'Maryland', 'Internal Medicine', 'In-network'),
#  (200919, 'LENOIR NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200920, 'CLOVIS NEUROLOGY', 'Maryland', 'Neurology', 'Out-of-network'),
#  (200921, 'DUNWOODY NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200922, 'BOURBONNAIS NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200923, 'PLANT NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200924, 'HOLBROOK NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200925, 'BOSTON NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200926, 'LARAMIE NEUROLOGY', 'Maryland', 'Neurology', 'In-network'),
#  (200927, 'LAYTON OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200928, 'BROKEN OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200929, 'BRIGHTON OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200930, 'EUCLID OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200931, 'IRONDEQUOIT OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200932, 'CASSELBERRY OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200933, 'OSSINING OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200934, 'MELROSE OBGYN', 'Maryland', 'OBGYN', 'In-network'),
#  (200935, 'ORCHARDS ONCOLOGY', 'Maryland', 'Oncology', 'In-network'),
#  (200936, 'LACEY ONCOLOGY', 'Maryland', 'Oncology', 'In-network'),
#  (200937, 'PASO ONCOLOGY', 'Maryland', 'Oncology', 'In-network'),
#  (200938, 'HUBER ONCOLOGY', 'Maryland', 'Oncology', 'In-network'),
#  (200939, 'LIVINGSTON ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200940, 'HIGH ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200941, 'BATTLE ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200942, 'JASPER ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200943, 'PELHAM ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200944, 'LANSDALE ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200945, 'DALLAS ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200946, 'PUYALLUP ORTHODONTICS', 'Maryland', 'Orthodontics', 'In-network'),
#  (200947, 'FERNLEY PEDIATRICS', 'Maryland', 'Pediatrics', 'In-network'),
#  (200948, 'THOMASVILLE PEDIATRICS', 'Maryland', 'Pediatrics', 'In-network'),
#  (200949, 'SYOSSET PEDIATRICS', 'Maryland', 'Pediatrics', 'Out-of-network'),
#  (200950, 'MUSTANG PEDIATRICS', 'Maryland', 'Pediatrics', 'In-network'),
#  (200951, 'OAKLEY PEDIATRICS', 'Maryland', 'Pediatrics', 'In-network'),
#  (200952, 'BLYTHEVILLE PEDIATRICS', 'Maryland', 'Pediatrics', 'In-network'),
#  (200953, 'FARMINGTON PEDIATRICS', 'Maryland', 'Pediatrics', 'In-network'),
#  (200954, 'CHATSWORTH PHYSICAL THERAPY', 'Maryland', 'Physical Therapy', 'In-network'),
#  (200955, 'MILTON PHYSICAL THERAPY', 'Maryland', 'Physical Therapy', 'In-network'),
#  (200956, 'DEERFIELD PHYSICAL THERAPY', 'Maryland', 'Physical Therapy', 'In-network'),
#  (200957, 'COTTAGE PHYSICAL THERAPY', 'Maryland', 'Physical Therapy', 'In-network'),
#  (200958, 'GARDEN PHYSICAL THERAPY', 'Maryland', 'Physical Therapy', 'In-network'),
#  (200959, 'SUMMERVILLE PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200960, 'POTTSTOWN PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200961, 'HERMOSA PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200962, 'COOPER PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200963, 'ESCONDIDO PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200964, 'GLOVERSVILLE PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200965, 'FLINT PRIMARY CARE', 'Maryland', 'Primary Care', 'Out-of-network'),
#  (200966, 'OAKLEY PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200967, 'MOSCOW PRIMARY CARE', 'Maryland', 'Primary Care', 'In-network'),
#  (200968, 'UNIONDALE URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200969, 'SELMA URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200970, 'WALLA URGENT CARE', 'Maryland', 'Urgent Care', 'Out-of-network'),
#  (200971, 'AMES URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200972, 'PITTSBURG URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200973, 'HOBART URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200974, 'LEBANON URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200975, 'MISSION URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200976, 'PINECREST URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200977, 'VESTAVIA URGENT CARE', 'Maryland', 'Urgent Care', 'In-network'),
#  (200978, 'SCOTTSDALE VISION', 'Maryland', 'Vision', 'In-network'),
#  (200979, 'BRIDGEWATER VISION', 'Maryland', 'Vision', 'In-network'),
#  (200980, 'LANDOVER VISION', 'Maryland', 'Vision', 'In-network'),
#  (200981, 'SELDEN VISION', 'Maryland', 'Vision', 'In-network'),
#  (200982, 'PORTSMOUTH VISION', 'Maryland', 'Vision', 'In-network'),
#  (200983, 'ECHO BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200984, 'MUNSTER BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200985, 'WARREN BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200986, 'SAND BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200987, 'CUMBERLAND BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200988, 'WORCESTER BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200989, 'CORONA BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200990, 'BRENT BEHAVIORAL HEALTH', 'Massachusetts', 'Behavioral Health', 'In-network'),
#  (200991, 'SPOKANE CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200992, 'GLENVIEW CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200993, 'BENICIA CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200994, 'MAPLE CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200995, 'MARINA CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200996, 'ANCHORAGE CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200997, 'GERMANTOWN CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  (200998, 'COOPER CARDIOLOGY', 'Massachusetts', 'Cardiology', 'Out-of-network'),
#  (200999, 'TORRANCE CARDIOLOGY', 'Massachusetts', 'Cardiology', 'In-network'),
#  ...]

# %%
# show tables to verify table creation
engine.execute('DROP TABLE providers')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1051, "Unknown table 'health_company.providers'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-97-5103c7885945> in <module>
#       1 # show tables to verify table creation
# ----> 2 engine.execute('DROP TABLE providers')
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2164
#    2165         connection = self._contextual_connect(close_with_result=True)
# -> 2166         return connection.execute(statement, *multiparams, **params)
#    2167
#    2168     def scalar(self, statement, *multiparams, **params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1242                 if not evt_handled:
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#    1246         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     548
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#     552     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1051, "Unknown table 'health_company.providers'")
# [SQL: DROP TABLE providers]
# (Background on this error at: http://sqlalche.me/e/2j85)

# %%
engine.dispose()
